# %%
import pandas as pd
import numpy as np
from Dataflow import *
# Out:
# C:\Users\geppi\Documents\Computer\eclipse-workspace\pandaSDMX\pandasdmx\remote.py:12: RuntimeWarning: optional dependency requests_cache is not installed; cache options to Session() have no effect
#   'to Session() have no effect', RuntimeWarning)

# %%
ilm = Dataflow('ILM_PUB', 'ECB', 'ECB.DISS')

# %%
ilm.contents_decoded([4, 1])
# Out:
#                                    Balance sheet item Frequency  \
# 6                            Banknotes in circulation   Monthly
# 26                           Banknotes in circulation    Weekly
# 11  Base money [sum(L010000 and L020100 and L020200)]   Monthly
# 45                               Capital and reserves    Weekly
# 10  Central government liabilities denominated in ...   Monthly
# 14  Claims on euro area residents denominated in f...    Weekly
# 15  Claims on non-euro area residents denominated ...    Weekly
# 13  Claims on non-euro area residents denominated ...    Weekly
# 42  Counterpart of Special Drawing Rights allocate...    Weekly
# 22                  Credits related to marginal calls    Weekly
# 7   Current accounts (covering the minimum reserve...   Monthly
# 27  Current accounts (covering the minimum reserve...    Weekly
# 37                           Debt certificates issued    Weekly
# 8                                    Deposit facility   Monthly
# ...

# %%
df = ilm.get(14)

# %%
df
# Out:
# FREQ                                                                                                                                                                                                                                      W
# REF_AREA                                                                                                                                                                                                                                 U2
# BS_REP_SECTOR                                                                                                                                                                                                                             C
# BS_ITEM                                                                                                                                                                                                                             A030000
# ...

# %%
df.index
# Out:
# DatetimeIndex(['1999-01-08', '1999-01-08', '1999-01-15', '1999-01-22',
#                '1999-01-29', '1999-02-05', '1999-02-12', '1999-02-19',
#                '1999-02-26', '1999-03-05',
#                ...
#                '2019-12-20', '2019-12-27', '2020-01-03', '2020-01-10',
#                '2020-01-17', '2020-01-24', '2020-01-31', '2020-02-07',
#                '2020-02-14', '2020-02-21'],
#               dtype='datetime64[ns]', name='TIME_PERIOD', length=1103, freq=None)

# %%
df.columns.levels[0]
# Out:
# Index(['W'], dtype='object', name='FREQ')

# %%
c_idx_dict = {level.name : level.all() for level in df.columns.levels}

# %%
df[tuple(c_idx_dict.values())]
# Out:
# TIME_PERIOD
# 1999-01-08     6704.0
# 1999-01-08     5255.0
# 1999-01-15     6541.0
# 1999-01-22     7277.0
# 1999-01-29     7385.0
#                ...
# 2020-01-24    19891.0
# 2020-01-31    20309.0
# 2020-02-07    19850.0
# 2020-02-14    20878.0
# 2020-02-21    22320.0
# Name: (W, U2, C, A030000, U2, Z06, E, 0, 6, P7D, EUR, Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart), Length: 1103, dtype: float64

# %%
ser = df.iloc[:,0]

# %%
ser.name
# Out:
# ('W',
#  'U2',
#  'C',
#  'A030000',
#  'U2',
#  'Z06',
#  'E',
#  '0',
#  '6',
#  'P7D',
#  'EUR',
#  'Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart')

# %%
ser
# Out:
# TIME_PERIOD
# 1999-01-08     6704.0
# 1999-01-08     5255.0
# 1999-01-15     6541.0
# 1999-01-22     7277.0
# 1999-01-29     7385.0
#                ...
# 2020-01-24    19891.0
# 2020-01-31    20309.0
# 2020-02-07    19850.0
# 2020-02-14    20878.0
# 2020-02-21    22320.0
# Name: (W, U2, C, A030000, U2, Z06, E, 0, 6, P7D, EUR, Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart), Length: 1103, dtype: float64

# %%
list(ilm.codemap.keys())
# Out:
# ['FREQ',
#  'REF_AREA',
#  'BS_REP_SECTOR',
#  'BS_ITEM',
#  'COUNT_AREA',
#  'CURRENCY_TRANS',
#  'OBS_STATUS',
#  'OBS_CONF',
#  'COLLECTION',
#  'COMPILING_ORG',
#  'DISS_ORG',
#  'DECIMALS',
#  'SOURCE_AGENCY',
#  'UNIT',
#  'UNIT_MULT']

# %%
ilm.dsd.dimensions.components
# Out:
# [<Dimension: FREQ>,
#  <Dimension: REF_AREA>,
#  <Dimension: BS_REP_SECTOR>,
#  <Dimension: BS_ITEM>,
#  <Dimension: COUNT_AREA>,
#  <Dimension: CURRENCY_TRANS>,
#  <TimeDimension: TIME_PERIOD>]

# %%
c_idx_dict
# Out:
# {'FREQ': 'W',
#  'REF_AREA': 'U2',
#  'BS_REP_SECTOR': 'C',
#  'BS_ITEM': 'A030000',
#  'COUNT_AREA': 'U2',
#  'CURRENCY_TRANS': 'Z06',
#  'COLLECTION': 'E',
#  'DECIMALS': '0',
#  'UNIT_MULT': '6',
#  'TIME_FORMAT': 'P7D',
#  'UNIT': 'EUR',
#  'TITLE_COMPL': 'Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart'}

# %%
ilm.dsd.attributes.components
# Out:
# [<DataAttribute: TIME_FORMAT>,
#  <DataAttribute: OBS_STATUS>,
#  <DataAttribute: OBS_CONF>,
#  <DataAttribute: OBS_PRE_BREAK>,
#  <DataAttribute: OBS_COM>,
#  <DataAttribute: BREAKS>,
#  <DataAttribute: COLLECTION>,
#  <DataAttribute: COMPILING_ORG>,
#  <DataAttribute: DISS_ORG>,
#  <DataAttribute: PUBL_ECB>,
#  <DataAttribute: PUBL_MU>,
#  <DataAttribute: PUBL_PUBLIC>,
#  <DataAttribute: AGG_EQUN>,
#  <DataAttribute: COMPILATION>,
#  <DataAttribute: COVERAGE>,
#  <DataAttribute: DECIMALS>,
#  <DataAttribute: SOURCE_AGENCY>,
#  <DataAttribute: TITLE>,
#  <DataAttribute: TITLE_COMPL>,
#  <DataAttribute: UNIT>,
#  <DataAttribute: UNIT_MULT>]

# %%
data_key = ilm.contents.iloc[14].to_dict()

# %%
data_msg = ilm.source.data(ilm.id, key=data_key, dsd=ilm.dsd)

# %%
df2 = sdmx.to_pandas(data_msg, datetime=True, dsd=ilm.dsd, attributes='', parse_time=False)

# %%
df2
# Out:
# FREQ                                                                                                                                                                                                                                      W
# REF_AREA                                                                                                                                                                                                                                 U2
# BS_REP_SECTOR                                                                                                                                                                                                                             C
# BS_ITEM                                                                                                                                                                                                                             A030000
# ...

# %%
dir(list(data_msg.data[0].series.keys())[0])
# Out:
# ['Config',
#  '__abstractmethods__',
#  '__add__',
#  '__annotations__',
#  '__class__',
#  '__config__',
#  '__contains__',
#  '__copy__',
#  '__custom_root_type__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__field_defaults__',
#  '__fields__',
#  '__fields_set__',
#  '__format__',
#  '__ge__',
#  '__get_validators__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__json_encoder__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__post_root_validators__',
#  '__pre_root_validators__',
#  '__pretty__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__repr_args__',
#  '__repr_name__',
#  '__repr_str__',
#  '__schema_cache__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
# ...

# %%
list(data_msg.data[0].series.keys())[0].values
# Out:
# DictLike([('FREQ', <KeyValue: FREQ=W>),
#           ('REF_AREA', <KeyValue: REF_AREA=U2>),
#           ('BS_REP_SECTOR', <KeyValue: BS_REP_SECTOR=C>),
#           ('BS_ITEM', <KeyValue: BS_ITEM=A030000>),
#           ('COUNT_AREA', <KeyValue: COUNT_AREA=U2>),
#           ('CURRENCY_TRANS', <KeyValue: CURRENCY_TRANS=Z06>),
#           ('COLLECTION', <KeyValue: COLLECTION=E>),
#           ('DECIMALS', <KeyValue: DECIMALS=0>),
#           ('UNIT_MULT', <KeyValue: UNIT_MULT=6>),
#           ('TIME_FORMAT', <KeyValue: TIME_FORMAT=P7D>),
#           ('UNIT', <KeyValue: UNIT=EUR>),
#           ('TITLE_COMPL',
#            <KeyValue: TITLE_COMPL=Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart>)])

# %%
dir(data_msg.data[0].series)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_apply_validators',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'move_to_end',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'validate',
#  'values']

# %%
data_msg.data[0].series.items()
# Out:
# odict_items([(<SeriesKey: FREQ=W, REF_AREA=U2, BS_REP_SECTOR=C, BS_ITEM=A030000, COUNT_AREA=U2, CURRENCY_TRANS=Z06, COLLECTION=E, DECIMALS=0, UNIT_MULT=6, TIME_FORMAT=P7D, UNIT=EUR, TITLE_COMPL=Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart>, [Observation(attached_attribute=DictLike([('OBS_STATUS', <AttributeValue: OBS_STATUS=A>)]), series_key=<SeriesKey: FREQ=W, REF_AREA=U2, BS_REP_SECTOR=C, BS_ITEM=A030000, COUNT_AREA=U2, CURRENCY_TRANS=Z06, COLLECTION=E, DECIMALS=0, UNIT_MULT=6, TIME_FORMAT=P7D, UNIT=EUR, TITLE_COMPL=Euro area (changing composition), Eurosystem reporting sector - Claims on euro area residents denominated in foreign currency, Non-Euro and non-euro area currencies combined - Euro area (changing composition) counterpart>, dimension=<Key: TIME_PERIOD=1998-W53>, value='6704', value_for=None, group_
# ...
